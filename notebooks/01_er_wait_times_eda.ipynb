# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')
sns.set()

# Load the dataset
df = pd.read_csv('../data/raw/ER_wait_time.csv')  # update file name if needed
df.head()
